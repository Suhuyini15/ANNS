# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./kc_house_data.csv")

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# ...

# %%
# df.head()
plt.figure(figsize = (10,6))
sns.distplot(df['price'])
# plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11124\93146555.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.countplot(x=df['bedrooms'],hue=df['bedrooms'])  # Specify 'x' parameter
plt.show()

# %%
see = df.drop(columns=['date'])
see.corr()['price'].sort_values()
# Out:
# zipcode         -0.053203
# id              -0.016762
# long             0.021626
# condition        0.036362
# yr_built         0.054012
# sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308350
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525138
# sqft_living15    0.585379
# sqft_above       0.605567
# grade            0.667434
# sqft_living      0.702035
# price            1.000000
# Name: price, dtype: float64

# %%
see.corr()['sqft_living'].sort_values()
# Out:
# zipcode         -0.199430
# condition       -0.058753
# id              -0.012258
# lat              0.052529
# yr_renovated     0.055363
# waterfront       0.103818
# sqft_lot         0.172826
# sqft_lot15       0.183286
# long             0.240223
# view             0.284611
# yr_built         0.318049
# floors           0.353949
# sqft_basement    0.435043
# bedrooms         0.576671
# price            0.702035
# bathrooms        0.754665
# sqft_living15    0.756420
# grade            0.762704
# sqft_above       0.876597
# sqft_living      1.000000
# Name: sqft_living, dtype: float64

# %%
plt.figure(figsize=(6,5))
sns.scatterplot(x='price',y='sqft_living', data=df)
plt.show()

# %%
sns.boxplot(x='bedrooms',y='price',data=df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='price',y='long',data=df)
# Out:
# <Axes: xlabel='price', ylabel='long'>

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='price',y='lat',data=df)
# Out:
# <Axes: xlabel='price', ylabel='lat'>

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='long',y='lat',data=df,hue='price')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
# import plotly.graph_objects as po
df.sort_values('price', ascending=False).head(20)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 4411   2470100110  20140804T000000  5570000.0         5       5.75
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# 1315   7558700030  20150413T000000  5300000.0         6       6.00
# 1164   1247600105  20141020T000000  5110800.0         5       5.25
# 8092   1924059029  20140617T000000  4668000.0         5       6.75
# 2626   7738500731  20140815T000000  4500000.0         5       5.50
# 8638   3835500195  20140618T000000  4489000.0         4       3.00
# 12370  6065300370  20150506T000000  4208000.0         5       6.00
# 4149   6447300265  20141014T000000  4000000.0         4       5.50
# 2085   8106100105  20141114T000000  3850000.0         4       4.25
# ...

# %%
len(df)*0.02
# Out:
# 432.26

# %%
normal = df.sort_values('price', ascending=False).iloc[428:]
normal
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15118  3616600250  20140527T000000  1600000.0         3       3.25
# 7404    524059148  20140606T000000  1600000.0         4       3.50
# 15874  7403200050  20141113T000000  1600000.0         3       2.25
# 1987   1118002090  20140628T000000  1600000.0         3       4.25
# 7433   9362000080  20150316T000000  1600000.0         5       3.50
# ...           ...              ...        ...       ...        ...
# 8274   3883800011  20141105T000000    82000.0         3       1.00
# 16198  3028200080  20150324T000000    81000.0         2       1.00
# 465    8658300340  20140523T000000    80000.0         1       0.75
# 15293    40000362  20140506T000000    78000.0         2       1.00
# 1149   3421079032  20150217T000000    75000.0         1       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15118         3790     19000     2.0           0     4  ...     10
# ...

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='long',y='lat',data=normal,edgecolor=None,alpha=0.2,palette='RdYlGn',hue='price')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
sns.boxplot(x='waterfront',y='price',data=df)
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %%
df = normal.drop('id', axis=1)

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 15118   2014-05-27
# 7404    2014-06-06
# 15874   2014-11-13
# 1987    2014-06-28
# 7433    2015-03-16
#            ...
# 8274    2014-11-05
# 16198   2015-03-24
# 465     2014-05-23
# 15293   2014-05-06
# 1149    2015-02-17
# Name: date, Length: 21185, dtype: datetime64[ns]

# %%
df['year'] = df['date'].apply(lambda date: date.year)
df['month'] = df['date'].apply(lambda date: date.month)

# %%
df.head()
# Out:
#             date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 15118 2014-05-27  1600000.0         3       3.25         3790     19000
# 7404  2014-06-06  1600000.0         4       3.50         4280      9583
# 15874 2014-11-13  1600000.0         3       2.25         3370     23065
# 1987  2014-06-28  1600000.0         3       4.25         2820      7200
# 7433  2015-03-16  1600000.0         5       3.50         4050     20925
#
#        floors  waterfront  view  condition  ...  sqft_basement  yr_built  \
# 15118     2.0           0     4          3  ...              0      1985
# 7404      2.0           0     0          3  ...              0      2005
# 15874     1.0           1     4          3  ...           1450      1980
# 1987      2.0           0     0          4  ...            360      1930
# 7433      2.0           0     3          3  ...           1030      1973
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# ...

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x='month',y='price',data=df)
# Out:
# <Axes: xlabel='month', ylabel='price'>

# %%
df.groupby('month').mean()['price']
# Out:
# month
# 1     481121.736842
# 2     481005.015460
# 3     508528.819422
# 4     530352.635036
# 5     511411.746079
# 6     521648.045412
# 7     512556.485688
# 8     501568.238045
# 9     497944.756726
# 10    504780.131779
# 11    488885.284682
# 12    490607.077670
# Name: price, dtype: float64

# %%
df.groupby('month').mean()['price'].plot()
# Out:
# <Axes: xlabel='month'>

# %%
df.groupby('year').mean()['price'].plot()
# Out:
# <Axes: xlabel='year'>

# %%
df= df.drop('date',axis=1)

# %%
df.head()
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 15118  1600000.0         3       3.25         3790     19000     2.0
# 7404   1600000.0         4       3.50         4280      9583     2.0
# 15874  1600000.0         3       2.25         3370     23065     1.0
# 1987   1600000.0         3       4.25         2820      7200     2.0
# 7433   1600000.0         5       3.50         4050     20925     2.0
#
#        waterfront  view  condition  grade  ...  sqft_basement  yr_built  \
# 15118           0     4          3     10  ...              0      1985
# 7404            0     0          3     11  ...              0      2005
# 15874           1     4          3     10  ...           1450      1980
# 1987            0     0          4     10  ...            360      1930
# 7433            0     3          3     10  ...           1030      1973
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# ...

# %%
df= df.drop('zipcode',axis=1)

# %%
df['yr_renovated'].value_counts ()
# Out:
# yr_renovated
# 0       20336
# 2014       89
# 2013       36
# 2005       34
# 2007       32
#         ...
# 1934        1
# 1948        1
# 1959        1
# 1951        1
# 1954        1
# Name: count, Length: 70, dtype: int64

# %%
df['sqft_basement'].value_counts()
# Out:
# sqft_basement
# 0       12976
# 600       219
# 500       211
# 700       211
# 800       204
#         ...
# 1852        1
# 588         1
# 1248        1
# 652         1
# 475         1
# Name: count, Length: 287, dtype: int64

# %%
X= df.drop('price', axis=1).values
y= df['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)
#We don't fit to test set so as not to assume prior information about the test set

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X_train.shape
# Out:
# (14829, 19)

# %%
model = Sequential()

model.add(Dense(64, activation='relu'))
model.add(Dense(52, activation='relu'))
model.add(Dense(44, activation='relu'))
model.add(Dense(36, activation='relu'))
model.add(Dense(28, activation='relu'))
model.add(Dense(16, activation='relu'))


model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

# %%
model.fit(x=X_train,y=y_train,validation_data=(X_test,y_test),batch_size=128,epochs=450)
# Out:
# Epoch 1/450
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 321474560000.0000 - val_loss: 301026770944.0000
# Epoch 2/450
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 177016766464.0000 - val_loss: 44556369920.0000
# Epoch 3/450
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42403512320.0000 - val_loss: 41144528896.0000
# Epoch 4/450
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 39165730816.0000 - val_loss: 37478580224.0000
# Epoch 5/450
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34951442432.0000 - val_loss: 33752416256.0000
# Epoch 6/450
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31964641280.0000 - val_loss: 30046369792.0000
# Epoch 7/450
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28841023488.0000 - val_loss: 26778273792.0000
# Epoch 8/450
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 25227841536.0000 - val_loss: 24377212928.0000
# Epoch 9/450
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()
# Out:
# <Axes: >

# %%
predictions = model.predict(X_test)
# Out:
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
 from sklearn.metrics import mean_absolute_error,mean_squared_error,explained_variance_score

# %%
np.sqrt(mean_squared_error(y_test,predictions))
# Out:
# 96880.19758185845

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 64385.01279548852

# %%
explained_variance_score(y_test,predictions)
# Out:
# 0.8613172703282435

# %%
plt.figure(figsize=(12,8))
plt.scatter(x=y_test,y=predictions)
plt.plot(y_test,y_test,'r')
plt.show()

# %%
single_house=df.drop('price',axis=1).iloc[0]
single_house = scaler.transform(single_house.values.reshape(-1,19))

# %%
model.predict(single_house)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# array([[1231980.4]], dtype=float32)

# %%
 df.head(1)
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 15118  1600000.0         3       3.25         3790     19000     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 15118           0     4          3     10        3790              0
#
#        yr_built  yr_renovated     lat     long  sqft_living15  sqft_lot15  \
# 15118      1985             0  47.724 -122.373           2740       18628
#
#        year  month
# 15118  2014      5
